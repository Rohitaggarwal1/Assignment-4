# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import seaborn as sns
sns.set()

# %%
df  = pd.read_csv("C:\\Users\\rachi\\Downloads\\MLP2 301095\\Real_fake_news.csv")

# %%
df.head(3)
# Out:
#    Unnamed: 0  Unnamed: 0.1               author  \
# 0           0             0         Jill Terreri
# 1           1             1  Eleanor Hildebrandt
# 2           2             2     Emily Zirkelbach
#
#                                            statement  \
# 0  New York is "leading the nation with the lowes...
# 1  “Iowa ranks 45th in the U.S. for internet conn...
# 2  “FUN FACT: West Virginia is home to zero billi...
#
#                                               source  target BinaryTarget  \
# 0  NYS Department of Corrections and Community Su...    True         REAL
# 1                                         Cindy Axne    True         REAL
# 2                                         David Gura    True         REAL
#
#    BinaryNumTarget
# 0                1
# 1                1
# 2                1

# %%
## DATA PRE-PROCESSING

#Finding out missing values in each column
print(df.isna().sum())
missing_status=df.isna().sum()
##print(df.isnull().sum())
# Out:
# Unnamed: 0         0
# Unnamed: 0.1       0
# author             0
# statement          0
# source             0
# target             0
# BinaryTarget       0
# BinaryNumTarget    0
# dtype: int64

# %%
df[df.duplicated(keep = 'last')]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 0.1, author, statement, source, target, BinaryTarget, BinaryNumTarget]
# Index: []

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'author', 'statement', 'source', 'target',
#        'BinaryTarget', 'BinaryNumTarget'],
#       dtype='object')

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df.author = le.fit_transform(df.author)
df.source = le.fit_transform(df.source)
df.head(3)
# Out:
#    Unnamed: 0  Unnamed: 0.1  author  \
# 0           0             0     128
# 1           1             1      82
# 2           2             2      87
#
#                                            statement  source  target  \
# 0  New York is "leading the nation with the lowes...    1035    True
# 1  “Iowa ranks 45th in the U.S. for internet conn...     247    True
# 2  “FUN FACT: West Virginia is home to zero billi...     321    True
#
#   BinaryTarget  BinaryNumTarget
# 0         REAL                1
# 1         REAL                1
# 2         REAL                1

# %%
X=df[['author','source']]
Y=df[['BinaryNumTarget']]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=1)

# %%
df.nunique()
# Out:
# Unnamed: 0         2436
# Unnamed: 0.1       2436
# author              318
# statement          4866
# source             1493
# target                2
# BinaryTarget          2
# BinaryNumTarget       2
# dtype: int64

# %%
knn = KNeighborsClassifier(n_neighbors=5, metric='euclidean')
knn.fit(X_train, Y_train)
# Out:
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(metric='euclidean')

# %%
Y_pred = knn.predict(X_test)

# %%
confusion_matrix(Y_test, Y_pred)
# Out:
# array([[477, 128],
#        [ 81, 532]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test, Y_pred)
# Out:
# 0.8284072249589491

# %%
error_rate = []
for i in range(1,40):
 knn = KNeighborsClassifier(n_neighbors=i)
 knn.fit(X_train,Y_train)
 pred_i = knn.predict(X_test)
 #print (pred_i)
 #print (1-accuracy_score(y_test, pred_i))
 error_rate.append(1-accuracy_score(Y_test, pred_i))

plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', 
         marker='o',markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
plt.show()
print("Minimum error:-",min(error_rate),"at K =",error_rate.index(min(error_rate))+1)
# Out:
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\rachi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Minimum error:- 0.17159277504105086 at K = 5

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier as dtree
from sklearn.tree import export_graphviz
# import graphviz

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
X=df[['author','source']]
Y=df[['BinaryNumTarget']]

# %%
ss = StandardScaler()
ss.fit(X)
X = ss.transform(X)
# Out:
# StandardScaler()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
                                                     X,
                                                     Y,
                                                     test_size = 0.3,
                                                     shuffle = True,
                                                     stratify = Y
                                                    )

# %%
X_train.shape 
print()

X_test.shape  
print()
# Out:
# (3409, 2)
# (1461, 2)

# %%
ct = dtree(
           criterion="gini",    
           max_depth=None      
           )

# %%
ct.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
Y_pred = ct.predict(X_test)

# %%
print("Accuracy:",accuracy_score(Y_test, Y_pred))
# Out:
# Accuracy: 0.8555783709787816

# %%
from sklearn import tree
plt.figure(figsize=(12,7))
tree.plot_tree(ct, filled=True, fontsize=12)
# Out:
# [Text(484.86701685418876, 372.5925, 'X[1] <= 1.597\ngini = 0.5\nsamples = 3409\nvalue = [1705, 1704]'),
#  Text(317.18937995406606, 356.73749999999995, 'X[1] <= -0.615\ngini = 0.493\nsamples = 2998\nvalue = [1328, 1670]'),
#  Text(131.4939713783497, 340.8825, 'X[1] <= -0.741\ngini = 0.473\nsamples = 1486\nvalue = [915, 571]'),
#  Text(58.545862629344654, 325.0275, 'X[1] <= -1.306\ngini = 0.426\nsamples = 699\nvalue = [215, 484]'),
#  Text(27.181958079066064, 309.1725, 'X[1] <= -1.473\ngini = 0.236\nsamples = 242\nvalue = [33, 209]'),
#  Text(13.857468824621915, 293.3175, 'X[0] <= -0.832\ngini = 0.423\nsamples = 69\nvalue = [21, 48]'),
#  Text(12.436189970814539, 277.4625, 'gini = 0.0\nsamples = 20\nvalue = [0, 20]'),
#  Text(15.27874767842929, 277.4625, 'X[1] <= -1.59\ngini = 0.49\nsamples = 49\nvalue = [21, 28]'),
#  Text(13.857468824621915, 261.60749999999996, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(16.700026532236667, 261.60749999999996, 'X[1] <= -1.48\ngini = 0.476\nsamples = 46\nvalue = [18, 28]'),
#  Text(15.27874767842929, 245.7525, 'X[1] <= -1.528\ngini = 0.463\nsamples = 44\nvalue = [16, 28]'),
#  Text(10.65959140355532, 229.8975, 'X[1] <= -1.539\ngini = 0.499\nsamples = 25\nvalue = [12, 13]'),
#  Text(5.685115415229504, 214.0425, 'X[0] <= -0.458\ngini = 0.375\nsamples = 16\nvalue = [4, 12]'),
#  Text(2.842557707614752, 198.1875, 'X[0] <= -0.687\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(1.421278853807376, 182.3325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(4.263836561422128, 182.3325, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(8.527673122844256, 198.1875, 'X[1] <= -1.542\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(7.10639426903688, 182.3325, 'X[0] <= 0.51\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(5.685115415229504, 166.4775, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(8.527673122844256, 166.4775, 'X[0] <= 0.744\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(7.10639426903688, 150.6225, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(9.948951976651632, 150.6225, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(9.948951976651632, 182.3325, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(15.634067391881135, 214.0425, 'X[0] <= 0.161\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(14.21278853807376, 198.1875, 'X[1] <= -1.535\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(12.791509684266384, 182.3325, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(15.634067391881135, 182.3325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(17.05534624568851, 198.1875, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(19.897903953303263, 229.8975, 'X[1] <= -1.493\ngini = 0.332\nsamples = 19\nvalue = [4, 15]'),
#  Text(18.476625099495887, 214.0425, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(21.31918280711064, 214.0425, 'X[1] <= -1.489\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(19.897903953303263, 198.1875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(22.740461660918015, 198.1875, 'X[1] <= -1.486\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(21.31918280711064, 182.3325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(24.16174051472539, 182.3325, 'X[1] <= -1.483\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(22.740461660918015, 166.4775, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(25.583019368532767, 166.4775, 'X[0] <= 0.265\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(24.16174051472539, 150.6225, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(27.004298222340143, 150.6225, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(18.121305386044043, 245.7525, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(40.506447333510216, 293.3175, 'X[1] <= -1.372\ngini = 0.129\nsamples = 173\nvalue = [12, 161]'),
#  Text(35.5319713451844, 277.4625, 'X[1] <= -1.411\ngini = 0.066\nsamples = 117\nvalue = [4, 113]'),
#  Text(34.11069249137702, 261.60749999999996, 'X[1] <= -1.417\ngini = 0.26\nsamples = 26\nvalue = [4, 22]'),
#  Text(32.68941363756964, 245.7525, 'X[1] <= -1.471\ngini = 0.211\nsamples = 25\nvalue = [3, 22]'),
#  Text(31.26813478376227, 229.8975, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(34.11069249137702, 229.8975, 'X[1] <= -1.468\ngini = 0.375\nsamples = 12\nvalue = [3, 9]'),
#  Text(32.68941363756964, 214.0425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(35.5319713451844, 214.0425, 'X[0] <= 0.302\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(34.11069249137702, 198.1875, 'X[0] <= 0.094\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(32.68941363756964, 182.3325, 'X[1] <= -1.434\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(31.26813478376227, 166.4775, 'X[0] <= -1.051\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(29.846855929954895, 150.6225, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(32.68941363756964, 150.6225, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(34.11069249137702, 166.4775, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(35.5319713451844, 182.3325, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(36.953250198991775, 198.1875, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(35.5319713451844, 245.7525, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(36.953250198991775, 261.60749999999996, 'gini = 0.0\nsamples = 91\nvalue = [0, 91]'),
#  Text(45.48092332183603, 277.4625, 'X[1] <= -1.37\ngini = 0.245\nsamples = 56\nvalue = [8, 48]'),
#  Text(44.05964446802865, 261.60749999999996, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(46.90220217564341, 261.60749999999996, 'X[0] <= 0.187\ngini = 0.222\nsamples = 55\nvalue = [7, 48]'),
#  Text(44.05964446802865, 245.7525, 'X[1] <= -1.339\ngini = 0.363\nsamples = 21\nvalue = [5, 16]'),
#  Text(42.63836561422128, 229.8975, 'X[1] <= -1.347\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(41.217086760413906, 214.0425, 'X[0] <= -0.375\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(39.79580790660653, 198.1875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(42.63836561422128, 198.1875, 'X[0] <= 0.036\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(41.217086760413906, 182.3325, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(44.05964446802865, 182.3325, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(44.05964446802865, 214.0425, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(45.48092332183603, 229.8975, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(49.744759883258155, 245.7525, 'X[0] <= 1.498\ngini = 0.111\nsamples = 34\nvalue = [2, 32]'),
#  Text(48.32348102945078, 229.8975, 'gini = 0.0\nsamples = 27\nvalue = [0, 27]'),
#  Text(51.166038737065534, 229.8975, 'X[1] <= -1.354\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(49.744759883258155, 214.0425, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(52.587317590872914, 214.0425, 'X[1] <= -1.343\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(51.166038737065534, 198.1875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(54.008596444680286, 198.1875, 'X[1] <= -1.323\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(52.587317590872914, 182.3325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(55.42987529848766, 182.3325, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(89.90976717962324, 309.1725, 'X[1] <= -1.297\ngini = 0.479\nsamples = 457\nvalue = [182, 275]'),
#  Text(56.4958344388432, 293.3175, 'X[0] <= -1.353\ngini = 0.12\nsamples = 125\nvalue = [117, 8]'),
#  Text(55.07455558503582, 277.4625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(57.91711329265057, 277.4625, 'X[1] <= -1.3\ngini = 0.107\nsamples = 124\nvalue = [117, 7]'),
#  Text(54.008596444680286, 261.60749999999996, 'X[0] <= 0.401\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(52.587317590872914, 245.7525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(55.42987529848766, 245.7525, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(61.82563014062085, 261.60749999999996, 'X[0] <= -0.806\ngini = 0.094\nsamples = 122\nvalue = [116, 6]'),
#  Text(58.27243300610242, 245.7525, 'X[0] <= -0.942\ngini = 0.033\nsamples = 60\nvalue = [59, 1]'),
#  Text(56.85115415229504, 229.8975, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(59.69371185990979, 229.8975, 'X[0] <= -0.921\ngini = 0.041\nsamples = 48\nvalue = [47, 1]'),
#  Text(58.27243300610242, 214.0425, 'gini = 0.049\nsamples = 40\nvalue = [39, 1]'),
#  Text(61.11499071371716, 214.0425, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(65.37882727513929, 245.7525, 'X[0] <= -0.65\ngini = 0.148\nsamples = 62\nvalue = [57, 5]'),
#  Text(63.95754842133192, 229.8975, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(66.80010612894667, 229.8975, 'X[0] <= -0.14\ngini = 0.123\nsamples = 61\nvalue = [57, 4]'),
#  Text(63.95754842133192, 214.0425, 'X[0] <= -0.187\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(62.53626956752454, 198.1875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(65.37882727513929, 198.1875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(69.64266383656143, 214.0425, 'X[0] <= 0.135\ngini = 0.098\nsamples = 58\nvalue = [55, 3]'),
#  Text(68.22138498275405, 198.1875, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(71.0639426903688, 198.1875, 'X[0] <= 0.255\ngini = 0.122\nsamples = 46\nvalue = [43, 3]'),
#  Text(69.64266383656143, 182.3325, 'gini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(72.48522154417617, 182.3325, 'X[0] <= 1.347\ngini = 0.093\nsamples = 41\nvalue = [39, 2]'),
#  Text(71.0639426903688, 166.4775, 'X[0] <= 1.202\ngini = 0.121\nsamples = 31\nvalue = [29, 2]'),
#  Text(69.64266383656143, 150.6225, 'X[0] <= 0.723\ngini = 0.064\nsamples = 30\nvalue = [29, 1]'),
#  Text(68.22138498275405, 134.7675, 'X[0] <= 0.588\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(66.80010612894667, 118.91250000000002, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(69.64266383656143, 118.91250000000002, 'gini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(71.0639426903688, 134.7675, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(72.48522154417617, 150.6225, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(73.90650039798355, 166.4775, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(123.32369992040329, 293.3175, 'X[1] <= -0.914\ngini = 0.315\nsamples = 332\nvalue = [65, 267]'),
#  Text(100.96631732555055, 277.4625, 'X[0] <= -0.827\ngini = 0.353\nsamples = 245\nvalue = [56, 189]'),
#  Text(86.69801008224994, 261.60749999999996, 'X[0] <= -1.098\ngini = 0.185\nsamples = 68\nvalue = [7, 61]'),
#  Text(85.27673122844256, 245.7525, 'X[0] <= -1.134\ngini = 0.278\nsamples = 42\nvalue = [7, 35]'),
#  Text(83.85545237463518, 229.8975, 'X[0] <= -1.191\ngini = 0.219\nsamples = 40\nvalue = [5, 35]'),
#  Text(81.01289466702043, 214.0425, 'X[1] <= -1.17\ngini = 0.124\nsamples = 30\nvalue = [2, 28]'),
#  Text(79.59161581321305, 198.1875, 'X[1] <= -1.185\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(78.17033695940567, 182.3325, 'X[1] <= -1.232\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(76.7490581055983, 166.4775, 'X[0] <= -1.327\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(75.32777925179093, 150.6225, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(78.17033695940567, 150.6225, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(79.59161581321305, 166.4775, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(81.01289466702043, 182.3325, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(82.43417352082781, 198.1875, 'gini = 0.0\nsamples = 24\nvalue = [0, 24]'),
#  Text(86.69801008224994, 214.0425, 'X[0] <= -1.165\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(85.27673122844256, 198.1875, 'X[1] <= -1.083\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(83.85545237463518, 182.3325, 'X[1] <= -1.182\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(82.43417352082781, 166.4775, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(85.27673122844256, 166.4775, 'X[1] <= -1.107\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(83.85545237463518, 150.6225, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(86.69801008224994, 150.6225, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(86.69801008224994, 182.3325, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(88.1192889360573, 198.1875, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(86.69801008224994, 229.8975, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(88.1192889360573, 245.7525, 'gini = 0.0\nsamples = 26\nvalue = [0, 26]'),
#  Text(115.23462456885116, 261.60749999999996, 'X[0] <= -0.806\ngini = 0.4\nsamples = 177\nvalue = [49, 128]'),
#  Text(113.81334571504378, 245.7525, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(116.65590342265853, 245.7525, 'X[1] <= -1.017\ngini = 0.376\nsamples = 171\nvalue = [43, 128]'),
#  Text(99.71159458742372, 229.8975, 'X[0] <= -0.577\ngini = 0.318\nsamples = 131\nvalue = [26, 105]'),
#  Text(92.38312549747944, 214.0425, 'X[0] <= -0.656\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(90.96184664367206, 198.1875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(93.80440435128682, 198.1875, 'X[1] <= -1.083\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(92.38312549747944, 182.3325, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(95.22568320509419, 182.3325, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(107.040063677368, 214.0425, 'X[0] <= -0.39\ngini = 0.294\nsamples = 123\nvalue = [22, 101]'),
#  Text(105.61878482356063, 198.1875, 'gini = 0.0\nsamples = 24\nvalue = [0, 24]'),
#  Text(108.46134253117538, 198.1875, 'X[0] <= -0.156\ngini = 0.346\nsamples = 99\nvalue = [22, 77]'),
#  Text(98.06824091270894, 182.3325, 'X[0] <= -0.208\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(95.22568320509419, 166.4775, 'X[0] <= -0.354\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(93.80440435128682, 150.6225, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(96.64696205890156, 150.6225, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(100.91079862032369, 166.4775, 'X[1] <= -1.164\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(99.48951976651631, 150.6225, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(102.33207747413107, 150.6225, 'X[1] <= -1.116\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(100.91079862032369, 134.7675, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(103.75335632793845, 134.7675, 'X[1] <= -1.095\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(102.33207747413107, 118.91250000000002, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(105.17463518174583, 118.91250000000002, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(118.85444414964181, 182.3325, 'X[0] <= 1.519\ngini = 0.3\nsamples = 87\nvalue = [16, 71]'),
#  Text(111.92570973733086, 166.4775, 'X[1] <= -1.232\ngini = 0.253\nsamples = 74\nvalue = [11, 63]'),
#  Text(110.50443088352348, 150.6225, 'gini = 0.0\nsamples = 19\nvalue = [0, 19]'),
#  Text(113.34698859113823, 150.6225, 'X[1] <= -1.226\ngini = 0.32\nsamples = 55\nvalue = [11, 44]'),
#  Text(111.92570973733086, 134.7675, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(114.76826744494561, 134.7675, 'X[0] <= -0.062\ngini = 0.282\nsamples = 53\nvalue = [9, 44]'),
#  Text(108.01719288936057, 118.91250000000002, 'X[1] <= -1.178\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(106.59591403555319, 103.0575, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(109.43847174316795, 103.0575, 'X[1] <= -1.113\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(108.01719288936057, 87.20249999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(110.85975059697532, 87.20249999999999, 'X[1] <= -1.054\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(109.43847174316795, 71.34750000000003, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(112.2810294507827, 71.34750000000003, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(121.51934200053064, 118.91250000000002, 'X[1] <= -1.058\ngini = 0.245\nsamples = 49\nvalue = [7, 42]'),
#  Text(120.09806314672326, 103.0575, 'X[1] <= -1.069\ngini = 0.301\nsamples = 38\nvalue = [7, 31]'),
#  Text(118.6767842929159, 87.20249999999999, 'X[1] <= -1.215\ngini = 0.239\nsamples = 36\nvalue = [5, 31]'),
#  Text(115.12358715839746, 71.34750000000003, 'X[0] <= 0.395\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(113.70230830459008, 55.49250000000001, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(116.54486601220484, 55.49250000000001, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(122.22998142743432, 71.34750000000003, 'X[0] <= 0.213\ngini = 0.208\nsamples = 34\nvalue = [4, 30]'),
#  Text(119.38742371981958, 55.49250000000001, 'X[1] <= -1.203\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(117.9661448660122, 39.63749999999999, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(120.80870257362696, 39.63749999999999, 'X[0] <= 0.177\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(119.38742371981958, 23.782500000000027, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(122.22998142743432, 23.782500000000027, 'X[1] <= -1.083\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(120.80870257362696, 7.927500000000009, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(123.6512602812417, 7.927500000000009, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(125.07253913504908, 55.49250000000001, 'X[0] <= 0.91\ngini = 0.137\nsamples = 27\nvalue = [2, 25]'),
#  Text(123.6512602812417, 39.63749999999999, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(126.49381798885646, 39.63749999999999, 'X[0] <= 0.983\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(125.07253913504908, 23.782500000000027, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(127.91509684266384, 23.782500000000027, 'X[1] <= -1.126\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(126.49381798885646, 7.927500000000009, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(129.3363756964712, 7.927500000000009, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(121.51934200053064, 87.20249999999999, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(122.94062085433802, 103.0575, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(125.78317856195277, 166.4775, 'X[0] <= 1.55\ngini = 0.473\nsamples = 13\nvalue = [5, 8]'),
#  Text(124.3618997081454, 150.6225, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(127.20445741576015, 150.6225, 'X[1] <= -1.24\ngini = 0.397\nsamples = 11\nvalue = [3, 8]'),
#  Text(125.78317856195277, 134.7675, 'X[1] <= -1.275\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(124.3618997081454, 118.91250000000002, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(127.20445741576015, 118.91250000000002, 'gini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(128.6257362695675, 134.7675, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(133.60021225789333, 229.8975, 'X[1] <= -0.992\ngini = 0.489\nsamples = 40\nvalue = [17, 23]'),
#  Text(130.75765455027857, 214.0425, 'X[0] <= 1.197\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(129.3363756964712, 198.1875, 'X[0] <= 0.983\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(127.91509684266384, 182.3325, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(130.75765455027857, 182.3325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(132.17893340408597, 198.1875, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(136.4427699655081, 214.0425, 'X[1] <= -0.967\ngini = 0.444\nsamples = 33\nvalue = [11, 22]'),
#  Text(135.02149111170073, 198.1875, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(137.86404881931546, 198.1875, 'X[1] <= -0.957\ngini = 0.497\nsamples = 24\nvalue = [11, 13]'),
#  Text(136.4427699655081, 182.3325, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(139.28532767312285, 182.3325, 'X[1] <= -0.93\ngini = 0.455\nsamples = 20\nvalue = [7, 13]'),
#  Text(135.7321305386044, 166.4775, 'X[1] <= -0.955\ngini = 0.337\nsamples = 14\nvalue = [3, 11]'),
#  Text(132.88957283098966, 150.6225, 'X[0] <= 1.269\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(131.46829397718227, 134.7675, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(134.31085168479703, 134.7675, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(138.57468824621915, 150.6225, 'X[0] <= 0.505\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(137.1534093924118, 134.7675, 'X[0] <= 0.078\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(135.7321305386044, 118.91250000000002, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(138.57468824621915, 118.91250000000002, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(139.99596710002652, 134.7675, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(142.83852480764128, 166.4775, 'X[0] <= 0.671\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(141.4172459538339, 150.6225, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(144.25980366144867, 150.6225, 'X[0] <= 1.384\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(142.83852480764128, 134.7675, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(145.68108251525604, 134.7675, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(145.68108251525604, 277.4625, 'X[1] <= -0.78\ngini = 0.185\nsamples = 87\nvalue = [9, 78]'),
#  Text(140.70660652693022, 261.60749999999996, 'X[1] <= -0.848\ngini = 0.082\nsamples = 70\nvalue = [3, 67]'),
#  Text(139.28532767312285, 245.7525, 'gini = 0.0\nsamples = 31\nvalue = [0, 31]'),
#  Text(142.1278853807376, 245.7525, 'X[1] <= -0.844\ngini = 0.142\nsamples = 39\nvalue = [3, 36]'),
#  Text(140.70660652693022, 229.8975, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(143.54916423454497, 229.8975, 'X[0] <= 0.817\ngini = 0.1\nsamples = 38\nvalue = [2, 36]'),
#  Text(142.1278853807376, 214.0425, 'gini = 0.0\nsamples = 24\nvalue = [0, 24]'),
#  Text(144.97044308835234, 214.0425, 'X[1] <= -0.812\ngini = 0.245\nsamples = 14\nvalue = [2, 12]'),
#  Text(143.54916423454497, 198.1875, 'X[0] <= 1.483\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(142.1278853807376, 182.3325, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(144.97044308835234, 182.3325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(146.39172194215973, 198.1875, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(150.65555850358186, 261.60749999999996, 'X[0] <= -0.572\ngini = 0.457\nsamples = 17\nvalue = [6, 11]'),
#  Text(147.8130007959671, 245.7525, 'X[1] <= -0.759\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(146.39172194215973, 229.8975, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(149.23427964977446, 229.8975, 'X[0] <= -1.02\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(147.8130007959671, 214.0425, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(150.65555850358186, 214.0425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(153.4981162111966, 245.7525, 'X[1] <= -0.776\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(152.07683735738922, 229.8975, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(154.91939506500398, 229.8975, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(204.44208012735473, 325.0275, 'X[1] <= -0.619\ngini = 0.197\nsamples = 787\nvalue = [700, 87]'),
#  Text(187.16465906075882, 309.1725, 'X[1] <= -0.736\ngini = 0.452\nsamples = 209\nvalue = [137, 72]'),
#  Text(172.15240116741842, 293.3175, 'X[0] <= 0.213\ngini = 0.278\nsamples = 150\nvalue = [125, 25]'),
#  Text(165.5789864685593, 277.4625, 'X[0] <= -0.14\ngini = 0.129\nsamples = 72\nvalue = [67, 5]'),
#  Text(162.02578933404087, 261.60749999999996, 'X[0] <= -0.187\ngini = 0.169\nsamples = 43\nvalue = [39, 4]'),
#  Text(160.60451048023347, 245.7525, 'X[0] <= -0.9\ngini = 0.133\nsamples = 42\nvalue = [39, 3]'),
#  Text(157.76195277261874, 229.8975, 'X[0] <= -1.264\ngini = 0.08\nsamples = 24\nvalue = [23, 1]'),
#  Text(156.34067391881135, 214.0425, 'X[1] <= -0.738\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(154.91939506500398, 198.1875, 'gini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(157.76195277261874, 198.1875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(159.1832316264261, 214.0425, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(163.44706818784823, 229.8975, 'X[0] <= -0.832\ngini = 0.198\nsamples = 18\nvalue = [16, 2]'),
#  Text(162.02578933404087, 214.0425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(164.86834704165562, 214.0425, 'X[0] <= -0.333\ngini = 0.111\nsamples = 17\nvalue = [16, 1]'),
#  Text(163.44706818784823, 198.1875, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(166.289625895463, 198.1875, 'X[0] <= -0.203\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(164.86834704165562, 182.3325, 'gini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(167.71090474927036, 182.3325, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(163.44706818784823, 245.7525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(169.13218360307775, 261.60749999999996, 'X[0] <= -0.094\ngini = 0.067\nsamples = 29\nvalue = [28, 1]'),
#  Text(167.71090474927036, 245.7525, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(170.55346245688511, 245.7525, 'X[0] <= -0.052\ngini = 0.074\nsamples = 26\nvalue = [25, 1]'),
#  Text(169.13218360307775, 229.8975, 'X[1] <= -0.738\ngini = 0.083\nsamples = 23\nvalue = [22, 1]'),
#  Text(167.71090474927036, 214.0425, 'gini = 0.087\nsamples = 22\nvalue = [21, 1]'),
#  Text(170.55346245688511, 214.0425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(171.97474131069248, 229.8975, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(178.72581586627751, 277.4625, 'X[0] <= 0.291\ngini = 0.381\nsamples = 78\nvalue = [58, 20]'),
#  Text(177.30453701247015, 261.60749999999996, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(180.1470947200849, 261.60749999999996, 'X[0] <= 1.556\ngini = 0.339\nsamples = 74\nvalue = [58, 16]'),
#  Text(178.72581586627751, 245.7525, 'X[0] <= 0.458\ngini = 0.327\nsamples = 73\nvalue = [58, 15]'),
#  Text(174.81729901830724, 229.8975, 'X[0] <= 0.359\ngini = 0.225\nsamples = 31\nvalue = [27, 4]'),
#  Text(173.39602016449987, 214.0425, 'gini = 0.238\nsamples = 29\nvalue = [25, 4]'),
#  Text(176.2385778721146, 214.0425, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(182.63433271424782, 229.8975, 'X[0] <= 0.666\ngini = 0.387\nsamples = 42\nvalue = [31, 11]'),
#  Text(179.08113557972936, 214.0425, 'X[0] <= 0.479\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(177.659856725922, 198.1875, 'gini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(180.50241443353676, 198.1875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(186.18752984876625, 214.0425, 'X[0] <= 1.056\ngini = 0.32\nsamples = 35\nvalue = [28, 7]'),
#  Text(183.3449721411515, 198.1875, 'X[0] <= 0.806\ngini = 0.278\nsamples = 24\nvalue = [20, 4]'),
#  Text(181.92369328734412, 182.3325, 'X[0] <= 0.739\ngini = 0.32\nsamples = 20\nvalue = [16, 4]'),
#  Text(180.50241443353676, 166.4775, 'gini = 0.266\nsamples = 19\nvalue = [16, 3]'),
#  Text(183.3449721411515, 166.4775, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(184.76625099495888, 182.3325, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(189.030087556381, 198.1875, 'X[0] <= 1.223\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(187.60880870257364, 182.3325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(190.45136641018837, 182.3325, 'X[0] <= 1.285\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(189.030087556381, 166.4775, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(191.87264526399576, 166.4775, 'X[0] <= 1.373\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(190.45136641018837, 150.6225, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(193.29392411780313, 150.6225, 'X[0] <= 1.498\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(191.87264526399576, 134.7675, 'gini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(194.7152029716105, 134.7675, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(181.56837357389227, 245.7525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(202.17691695409923, 293.3175, 'X[1] <= -0.646\ngini = 0.324\nsamples = 59\nvalue = [12, 47]'),
#  Text(194.00456354470683, 277.4625, 'X[1] <= -0.708\ngini = 0.241\nsamples = 50\nvalue = [7, 43]'),
#  Text(189.030087556381, 261.60749999999996, 'X[1] <= -0.725\ngini = 0.375\nsamples = 12\nvalue = [3, 9]'),
#  Text(187.60880870257364, 245.7525, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(190.45136641018837, 245.7525, 'X[1] <= -0.718\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(189.030087556381, 229.8975, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(191.87264526399576, 229.8975, 'X[0] <= -0.016\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(190.45136641018837, 214.0425, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(193.29392411780313, 214.0425, 'X[1] <= -0.713\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(191.87264526399576, 198.1875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(194.7152029716105, 198.1875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(198.97903953303262, 261.60749999999996, 'X[0] <= -1.15\ngini = 0.188\nsamples = 38\nvalue = [4, 34]'),
#  Text(196.1364818254179, 245.7525, 'X[1] <= -0.684\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(194.7152029716105, 229.8975, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(197.55776067922525, 229.8975, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(201.82159724064738, 245.7525, 'X[1] <= -0.668\ngini = 0.153\nsamples = 36\nvalue = [3, 33]'),
#  Text(200.40031838684, 229.8975, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(203.24287609445477, 229.8975, 'X[0] <= 0.265\ngini = 0.278\nsamples = 18\nvalue = [3, 15]'),
#  Text(201.82159724064738, 214.0425, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(204.66415494826214, 214.0425, 'X[0] <= 0.468\ngini = 0.397\nsamples = 11\nvalue = [3, 8]'),
#  Text(203.24287609445477, 198.1875, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(206.0854338020695, 198.1875, 'X[1] <= -0.661\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(204.66415494826214, 182.3325, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(207.5067126558769, 182.3325, 'X[0] <= 1.556\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(206.0854338020695, 166.4775, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(208.92799150968426, 166.4775, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(210.34927036349166, 277.4625, 'X[1] <= -0.631\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(208.92799150968426, 261.60749999999996, 'X[0] <= 0.114\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(207.5067126558769, 245.7525, 'X[0] <= -0.63\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(206.0854338020695, 229.8975, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(208.92799150968426, 229.8975, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(210.34927036349166, 245.7525, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(211.77054921729902, 261.60749999999996, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(221.71950119395063, 309.1725, 'X[0] <= -1.275\ngini = 0.051\nsamples = 578\nvalue = [563, 15]'),
#  Text(214.61310692491378, 293.3175, 'X[0] <= -1.436\ngini = 0.142\nsamples = 39\nvalue = [36, 3]'),
#  Text(213.19182807110639, 277.4625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(216.03438577872114, 277.4625, 'X[0] <= -1.342\ngini = 0.153\nsamples = 36\nvalue = [33, 3]'),
#  Text(214.61310692491378, 261.60749999999996, 'gini = 0.147\nsamples = 25\nvalue = [23, 2]'),
#  Text(217.4556646325285, 261.60749999999996, 'gini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(228.82589546298752, 293.3175, 'X[0] <= -0.609\ngini = 0.044\nsamples = 539\nvalue = [527, 12]'),
#  Text(221.71950119395063, 277.4625, 'X[0] <= -0.869\ngini = 0.009\nsamples = 224\nvalue = [223, 1]'),
#  Text(220.29822234014327, 261.60749999999996, 'gini = 0.0\nsamples = 161\nvalue = [161, 0]'),
#  Text(223.14078004775803, 261.60749999999996, 'X[0] <= -0.734\ngini = 0.031\nsamples = 63\nvalue = [62, 1]'),
#  Text(221.71950119395063, 245.7525, 'gini = 0.038\nsamples = 52\nvalue = [51, 1]'),
#  Text(224.5620589015654, 245.7525, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(235.9322897320244, 277.4625, 'X[0] <= 0.328\ngini = 0.067\nsamples = 315\nvalue = [304, 11]'),
#  Text(230.2471743167949, 261.60749999999996, 'X[0] <= 0.255\ngini = 0.254\nsamples = 47\nvalue = [40, 7]'),
#  Text(227.40461660918015, 245.7525, 'X[0] <= -0.047\ngini = 0.193\nsamples = 37\nvalue = [33, 4]'),
#  Text(225.9833377553728, 229.8975, 'X[0] <= -0.229\ngini = 0.231\nsamples = 30\nvalue = [26, 4]'),
#  Text(223.14078004775803, 214.0425, 'X[0] <= -0.286\ngini = 0.153\nsamples = 24\nvalue = [22, 2]'),
#  Text(221.71950119395063, 198.1875, 'X[0] <= -0.349\ngini = 0.198\nsamples = 18\nvalue = [16, 2]'),
#  Text(220.29822234014327, 182.3325, 'X[0] <= -0.546\ngini = 0.111\nsamples = 17\nvalue = [16, 1]'),
#  Text(218.8769434863359, 166.4775, 'gini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(221.71950119395063, 166.4775, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(223.14078004775803, 182.3325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(224.5620589015654, 198.1875, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(228.82589546298752, 214.0425, 'X[0] <= -0.203\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(227.40461660918015, 198.1875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(230.2471743167949, 198.1875, 'X[0] <= -0.14\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(228.82589546298752, 182.3325, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(231.66845317060228, 182.3325, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(228.82589546298752, 229.8975, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(233.08973202440967, 245.7525, 'X[0] <= 0.291\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(231.66845317060228, 229.8975, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(234.51101087821704, 229.8975, 'gini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(241.61740514725392, 261.60749999999996, 'X[0] <= 0.864\ngini = 0.029\nsamples = 268\nvalue = [264, 4]'),
#  Text(238.77484743963916, 245.7525, 'X[0] <= 0.723\ngini = 0.053\nsamples = 74\nvalue = [72, 2]'),
#  Text(237.3535685858318, 229.8975, 'gini = 0.0\nsamples = 44\nvalue = [44, 0]'),
#  Text(240.19612629344653, 229.8975, 'X[0] <= 0.791\ngini = 0.124\nsamples = 30\nvalue = [28, 2]'),
#  Text(238.77484743963916, 214.0425, 'gini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(241.61740514725392, 214.0425, 'gini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(244.45996285486865, 245.7525, 'X[0] <= 1.368\ngini = 0.02\nsamples = 194\nvalue = [192, 2]'),
#  Text(243.03868400106128, 229.8975, 'gini = 0.0\nsamples = 112\nvalue = [112, 0]'),
#  Text(245.88124170867604, 229.8975, 'X[0] <= 1.498\ngini = 0.048\nsamples = 82\nvalue = [80, 2]'),
#  Text(244.45996285486865, 214.0425, 'gini = 0.049\nsamples = 79\nvalue = [77, 2]'),
#  Text(247.3025205624834, 214.0425, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(502.88478852978244, 340.8825, 'X[1] <= 1.357\ngini = 0.397\nsamples = 1512\nvalue = [413, 1099]'),
#  Text(395.7744589911117, 325.0275, 'X[1] <= -0.383\ngini = 0.37\nsamples = 1342\nvalue = [329, 1013]'),
#  Text(292.07280445741577, 309.1725, 'X[1] <= -0.394\ngini = 0.489\nsamples = 246\nvalue = [105, 141]'),
#  Text(279.99193420005304, 293.3175, 'X[1] <= -0.469\ngini = 0.298\nsamples = 170\nvalue = [31, 139]'),
#  Text(266.48978508888297, 277.4625, 'X[1] <= -0.502\ngini = 0.398\nsamples = 95\nvalue = [26, 69]'),
#  Text(256.5408331122314, 261.60749999999996, 'X[0] <= 0.323\ngini = 0.219\nsamples = 64\nvalue = [8, 56]'),
#  Text(252.98763597771293, 245.7525, 'X[1] <= -0.583\ngini = 0.057\nsamples = 34\nvalue = [1, 33]'),
#  Text(251.56635712390553, 229.8975, 'X[1] <= -0.59\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(250.14507827009817, 214.0425, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(252.98763597771293, 214.0425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(254.4089148315203, 229.8975, 'gini = 0.0\nsamples = 26\nvalue = [0, 26]'),
#  Text(260.0940302467498, 245.7525, 'X[0] <= 0.468\ngini = 0.358\nsamples = 30\nvalue = [7, 23]'),
#  Text(257.251472539135, 229.8975, 'X[1] <= -0.519\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(255.83019368532769, 214.0425, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(258.6727513929424, 214.0425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(262.93658795436454, 229.8975, 'X[0] <= 1.399\ngini = 0.211\nsamples = 25\nvalue = [3, 22]'),
#  Text(261.51530910055715, 214.0425, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(264.35786680817193, 214.0425, 'X[0] <= 1.472\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(262.93658795436454, 198.1875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(265.7791456619793, 198.1875, 'X[0] <= 1.566\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(264.35786680817193, 182.3325, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(267.20042451578666, 182.3325, 'X[1] <= -0.542\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(265.7791456619793, 166.4775, 'X[1] <= -0.567\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(264.35786680817193, 150.6225, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(267.20042451578666, 150.6225, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(268.62170336959406, 166.4775, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(276.4387370655346, 261.60749999999996, 'X[1] <= -0.484\ngini = 0.487\nsamples = 31\nvalue = [18, 13]'),
#  Text(275.0174582117273, 245.7525, 'X[0] <= -0.822\ngini = 0.499\nsamples = 25\nvalue = [12, 13]'),
#  Text(271.4642610772088, 229.8975, 'X[0] <= -1.02\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(270.04298222340145, 214.0425, 'X[0] <= -1.238\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(268.62170336959406, 198.1875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(271.4642610772088, 198.1875, 'gini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(272.8855399310162, 214.0425, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(278.5706553462457, 229.8975, 'X[1] <= -0.49\ngini = 0.43\nsamples = 16\nvalue = [5, 11]'),
#  Text(275.7280976386309, 214.0425, 'X[0] <= 0.619\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(274.3068187848236, 198.1875, 'X[0] <= -0.52\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(272.8855399310162, 182.3325, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(275.7280976386309, 182.3325, 'X[1] <= -0.497\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(274.3068187848236, 166.4775, 'X[0] <= -0.395\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(272.8855399310162, 150.6225, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(275.7280976386309, 150.6225, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(277.1493764924383, 166.4775, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(277.1493764924383, 198.1875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(281.41321305386043, 214.0425, 'X[0] <= 1.467\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(279.99193420005304, 198.1875, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(282.8344919076678, 198.1875, 'gini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(277.860015919342, 245.7525, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(293.4940833112231, 277.4625, 'X[1] <= -0.4\ngini = 0.124\nsamples = 75\nvalue = [5, 70]'),
#  Text(289.9408861767047, 261.60749999999996, 'X[1] <= -0.42\ngini = 0.104\nsamples = 73\nvalue = [4, 69]'),
#  Text(287.09832846908995, 245.7525, 'X[1] <= -0.424\ngini = 0.236\nsamples = 22\nvalue = [3, 19]'),
#  Text(285.67704961528256, 229.8975, 'X[1] <= -0.456\ngini = 0.172\nsamples = 21\nvalue = [2, 19]'),
#  Text(284.2557707614752, 214.0425, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(287.09832846908995, 214.0425, 'X[1] <= -0.454\ngini = 0.278\nsamples = 12\nvalue = [2, 10]'),
#  Text(285.67704961528256, 198.1875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(288.51960732289734, 198.1875, 'X[1] <= -0.445\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(287.09832846908995, 182.3325, 'X[1] <= -0.448\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(285.67704961528256, 166.4775, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(288.51960732289734, 166.4775, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(289.9408861767047, 182.3325, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(288.51960732289734, 229.8975, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(292.78344388431947, 245.7525, 'X[1] <= -0.418\ngini = 0.038\nsamples = 51\nvalue = [1, 50]'),
#  Text(291.3621650305121, 229.8975, 'gini = 0.0\nsamples = 46\nvalue = [0, 46]'),
#  Text(294.2047227381268, 229.8975, 'X[0] <= -1.051\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(292.78344388431947, 214.0425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(295.6260015919342, 214.0425, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(297.0472804457416, 261.60749999999996, 'X[0] <= 0.229\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(295.6260015919342, 245.7525, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(298.46855929954893, 245.7525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(304.15367471477845, 293.3175, 'X[1] <= -0.39\ngini = 0.051\nsamples = 76\nvalue = [74, 2]'),
#  Text(301.3111170071637, 277.4625, 'X[1] <= -0.392\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(299.8898381533563, 261.60749999999996, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(302.73239586097105, 261.60749999999996, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(306.9962324223932, 277.4625, 'X[0] <= -0.442\ngini = 0.027\nsamples = 72\nvalue = [71, 1]'),
#  Text(305.57495356858584, 261.60749999999996, 'X[0] <= -0.484\ngini = 0.057\nsamples = 34\nvalue = [33, 1]'),
#  Text(304.15367471477845, 245.7525, 'gini = 0.0\nsamples = 33\nvalue = [33, 0]'),
#  Text(306.9962324223932, 245.7525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(308.41751127620057, 261.60749999999996, 'gini = 0.0\nsamples = 38\nvalue = [38, 0]'),
#  Text(499.47611352480766, 309.1725, 'X[0] <= 0.988\ngini = 0.325\nsamples = 1096\nvalue = [224, 872]'),
#  Text(434.704522088087, 293.3175, 'X[0] <= 0.801\ngini = 0.36\nsamples = 803\nvalue = [189, 614]'),
#  Text(335.54117471477844, 277.4625, 'X[0] <= -1.181\ngini = 0.345\nsamples = 772\nvalue = [171, 601]'),
#  Text(313.3919872645264, 261.60749999999996, 'X[1] <= 0.941\ngini = 0.19\nsamples = 141\nvalue = [15, 126]'),
#  Text(309.83879013000796, 245.7525, 'X[0] <= -1.337\ngini = 0.091\nsamples = 105\nvalue = [5, 100]'),
#  Text(308.41751127620057, 229.8975, 'X[0] <= -1.358\ngini = 0.16\nsamples = 57\nvalue = [5, 52]'),
#  Text(306.9962324223932, 214.0425, 'gini = 0.0\nsamples = 30\nvalue = [0, 30]'),
#  Text(309.83879013000796, 214.0425, 'X[1] <= 0.727\ngini = 0.302\nsamples = 27\nvalue = [5, 22]'),
#  Text(308.41751127620057, 198.1875, 'X[1] <= 0.685\ngini = 0.34\nsamples = 23\nvalue = [5, 18]'),
#  Text(306.9962324223932, 182.3325, 'X[1] <= -0.178\ngini = 0.298\nsamples = 22\nvalue = [4, 18]'),
#  Text(305.57495356858584, 166.4775, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(308.41751127620057, 166.4775, 'X[1] <= -0.039\ngini = 0.332\nsamples = 19\nvalue = [4, 15]'),
#  Text(306.9962324223932, 150.6225, 'gini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(309.83879013000796, 150.6225, 'X[1] <= 0.367\ngini = 0.231\nsamples = 15\nvalue = [2, 13]'),
#  Text(308.41751127620057, 134.7675, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(311.26006898381536, 134.7675, 'X[1] <= 0.61\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(309.83879013000796, 118.91250000000002, 'X[1] <= 0.521\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(308.41751127620057, 103.0575, 'X[1] <= 0.391\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(306.9962324223932, 87.20249999999999, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(309.83879013000796, 87.20249999999999, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(311.26006898381536, 103.0575, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(312.6813478376227, 118.91250000000002, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(309.83879013000796, 182.3325, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(311.26006898381536, 198.1875, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(311.26006898381536, 229.8975, 'gini = 0.0\nsamples = 48\nvalue = [0, 48]'),
#  Text(316.9451843990448, 245.7525, 'X[0] <= -1.337\ngini = 0.401\nsamples = 36\nvalue = [10, 26]'),
#  Text(315.5239055452375, 229.8975, 'X[0] <= -1.389\ngini = 0.491\nsamples = 23\nvalue = [10, 13]'),
#  Text(314.1026266914301, 214.0425, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(316.9451843990448, 214.0425, 'X[1] <= 1.022\ngini = 0.408\nsamples = 14\nvalue = [10, 4]'),
#  Text(314.1026266914301, 198.1875, 'X[1] <= 0.946\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(312.6813478376227, 182.3325, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(315.5239055452375, 182.3325, 'X[1] <= 0.963\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(314.1026266914301, 166.4775, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(316.9451843990448, 166.4775, 'X[1] <= 0.995\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(315.5239055452375, 150.6225, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(318.3664632528522, 150.6225, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(319.7877421066596, 198.1875, 'X[0] <= -1.363\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(318.3664632528522, 182.3325, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(321.20902096046694, 182.3325, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(318.3664632528522, 229.8975, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(357.69036216503054, 261.60749999999996, 'X[0] <= -1.165\ngini = 0.372\nsamples = 631\nvalue = [156, 475]'),
#  Text(331.1579729371186, 245.7525, 'X[1] <= 0.883\ngini = 0.238\nsamples = 29\nvalue = [25, 4]'),
#  Text(329.73669408331125, 229.8975, 'X[1] <= 0.47\ngini = 0.32\nsamples = 20\nvalue = [16, 4]'),
#  Text(326.89413637569646, 214.0425, 'X[1] <= 0.033\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(325.47285752188907, 198.1875, 'X[1] <= -0.043\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(324.05157866808173, 182.3325, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(326.89413637569646, 182.3325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(328.31541522950386, 198.1875, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(332.579251790926, 214.0425, 'X[1] <= 0.523\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(331.1579729371186, 198.1875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(334.0005306447334, 198.1875, 'X[1] <= 0.851\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(332.579251790926, 182.3325, 'X[1] <= 0.58\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(331.1579729371186, 166.4775, 'X[1] <= 0.53\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(329.73669408331125, 150.6225, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(332.579251790926, 150.6225, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(334.0005306447334, 166.4775, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(335.4218094985407, 182.3325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(332.579251790926, 229.8975, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(384.2227513929424, 245.7525, 'X[0] <= -0.962\ngini = 0.341\nsamples = 602\nvalue = [131, 471]'),
#  Text(336.8430883523481, 229.8975, 'X[1] <= 1.138\ngini = 0.034\nsamples = 58\nvalue = [1, 57]'),
#  Text(335.4218094985407, 214.0425, 'gini = 0.0\nsamples = 52\nvalue = [0, 52]'),
#  Text(338.2643672061555, 214.0425, 'X[1] <= 1.149\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(336.8430883523481, 198.1875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(339.68564605996283, 198.1875, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(431.60241443353675, 229.8975, 'X[1] <= 0.289\ngini = 0.364\nsamples = 544\nvalue = [130, 414]'),
#  Text(366.29020960466966, 214.0425, 'X[1] <= -0.242\ngini = 0.438\nsamples = 191\nvalue = [62, 129]'),
#  Text(342.5282037675776, 198.1875, 'X[0] <= -0.947\ngini = 0.188\nsamples = 38\nvalue = [4, 34]'),
#  Text(341.10692491377023, 182.3325, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(343.94948262138496, 182.3325, 'X[1] <= -0.254\ngini = 0.149\nsamples = 37\nvalue = [3, 34]'),
#  Text(342.5282037675776, 166.4775, 'X[1] <= -0.257\ngini = 0.198\nsamples = 27\nvalue = [3, 24]'),
#  Text(341.10692491377023, 150.6225, 'X[1] <= -0.284\ngini = 0.142\nsamples = 26\nvalue = [2, 24]'),
#  Text(338.2643672061555, 134.7675, 'X[1] <= -0.366\ngini = 0.091\nsamples = 21\nvalue = [1, 20]'),
#  Text(336.8430883523481, 118.91250000000002, 'X[1] <= -0.371\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(335.4218094985407, 103.0575, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
# ...
#  Text(541.6849031573362, 150.6225, 'X[1] <= 0.881\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(540.2636243035288, 134.7675, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(543.1061820111436, 134.7675, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(548.791297426373, 166.4775, 'X[1] <= 1.294\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(547.3700185725656, 150.6225, 'X[1] <= 0.881\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(545.9487397187582, 134.7675, 'X[1] <= 0.388\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(544.527460864951, 118.91250000000002, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(547.3700185725656, 118.91250000000002, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(548.791297426373, 134.7675, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(550.2125762801804, 150.6225, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(545.9487397187582, 198.1875, 'gini = 0.0\nsamples = 46\nvalue = [0, 46]'),
#  Text(561.5828071106395, 214.0425, 'X[1] <= 1.275\ngini = 0.375\nsamples = 44\nvalue = [11, 33]'),
#  Text(560.1615282568321, 198.1875, 'X[1] <= 1.218\ngini = 0.357\nsamples = 43\nvalue = [10, 33]'),
#  Text(558.7402494030247, 182.3325, 'X[1] <= 0.573\ngini = 0.415\nsamples = 34\nvalue = [10, 24]'),
#  Text(554.4764128416025, 166.4775, 'X[1] <= 0.281\ngini = 0.255\nsamples = 20\nvalue = [3, 17]'),
#  Text(553.0551339877952, 150.6225, 'X[1] <= 0.055\ngini = 0.375\nsamples = 12\nvalue = [3, 9]'),
#  Text(551.6338551339878, 134.7675, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(554.4764128416025, 134.7675, 'X[1] <= 0.105\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(553.0551339877952, 118.91250000000002, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(555.8976916954099, 118.91250000000002, 'X[1] <= 0.273\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(554.4764128416025, 103.0575, 'X[1] <= 0.201\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(553.0551339877952, 87.20249999999999, 'X[1] <= 0.153\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(551.6338551339878, 71.34750000000003, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(554.4764128416025, 71.34750000000003, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(555.8976916954099, 87.20249999999999, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(557.3189705492173, 103.0575, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(555.8976916954099, 150.6225, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(563.0040859644467, 166.4775, 'X[0] <= 1.509\ngini = 0.5\nsamples = 14\nvalue = [7, 7]'),
#  Text(561.5828071106395, 150.6225, 'X[1] <= 0.625\ngini = 0.486\nsamples = 12\nvalue = [5, 7]'),
#  Text(560.1615282568321, 134.7675, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(563.0040859644467, 134.7675, 'X[1] <= 1.182\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(561.5828071106395, 118.91250000000002, 'X[1] <= 0.96\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(560.1615282568321, 103.0575, 'X[1] <= 0.902\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(558.7402494030247, 87.20249999999999, 'X[1] <= 0.791\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(557.3189705492173, 71.34750000000003, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(560.1615282568321, 71.34750000000003, 'X[1] <= 0.822\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(558.7402494030247, 55.49250000000001, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(561.5828071106395, 55.49250000000001, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(561.5828071106395, 87.20249999999999, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(563.0040859644467, 103.0575, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(564.4253648182541, 118.91250000000002, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(564.4253648182541, 150.6225, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(561.5828071106395, 182.3325, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(563.0040859644467, 198.1875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(555.8976916954099, 229.8975, 'gini = 0.0\nsamples = 70\nvalue = [0, 70]'),
#  Text(579.7041124966835, 245.7525, 'X[0] <= 1.582\ngini = 0.353\nsamples = 48\nvalue = [11, 37]'),
#  Text(573.6636773680021, 229.8975, 'X[1] <= 0.757\ngini = 0.5\nsamples = 20\nvalue = [10, 10]'),
#  Text(568.6892013796763, 214.0425, 'X[1] <= 0.188\ngini = 0.459\nsamples = 14\nvalue = [5, 9]'),
#  Text(565.8466436720615, 198.1875, 'X[1] <= -0.13\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(564.4253648182541, 182.3325, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(567.2679225258689, 182.3325, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(571.5317590872911, 198.1875, 'X[1] <= 0.406\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(570.1104802334837, 182.3325, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(572.9530379410984, 182.3325, 'X[1] <= 0.547\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(571.5317590872911, 166.4775, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(574.3743167949058, 166.4775, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(578.638153356328, 214.0425, 'X[1] <= 0.998\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(577.2168745025206, 198.1875, 'X[1] <= 0.902\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(575.7955956487132, 182.3325, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(578.638153356328, 182.3325, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(580.0594322101354, 198.1875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(585.7445476253648, 229.8975, 'X[0] <= 1.66\ngini = 0.069\nsamples = 28\nvalue = [1, 27]'),
#  Text(584.3232687715574, 214.0425, 'X[0] <= 1.649\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(582.90198991775, 198.1875, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(585.7445476253648, 198.1875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(587.1658264791722, 214.0425, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(609.9951180684532, 325.0275, 'X[0] <= -1.191\ngini = 0.5\nsamples = 170\nvalue = [84, 86]'),
#  Text(608.5738392146458, 309.1725, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(611.4163969222606, 309.1725, 'X[0] <= -1.165\ngini = 0.498\nsamples = 159\nvalue = [84, 75]'),
#  Text(597.8254178827275, 293.3175, 'X[1] <= 1.517\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(596.4041390289201, 277.4625, 'X[1] <= 1.472\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(594.9828601751127, 261.60749999999996, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(597.8254178827275, 261.60749999999996, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(599.2466967365349, 277.4625, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(625.0073759617936, 293.3175, 'X[1] <= 1.535\ngini = 0.5\nsamples = 146\nvalue = [72, 74]'),
#  Text(611.6828867073494, 277.4625, 'X[1] <= 1.471\ngini = 0.491\nsamples = 102\nvalue = [44, 58]'),
#  Text(600.6679755903423, 261.60749999999996, 'X[1] <= 1.443\ngini = 0.49\nsamples = 70\nvalue = [40, 30]'),
#  Text(592.8509418944017, 245.7525, 'X[1] <= 1.366\ngini = 0.492\nsamples = 48\nvalue = [21, 27]'),
#  Text(591.4296630405943, 229.8975, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(594.2722207482091, 229.8975, 'X[1] <= 1.418\ngini = 0.48\nsamples = 45\nvalue = [18, 27]'),
#  Text(590.008384186787, 214.0425, 'X[0] <= 1.509\ngini = 0.499\nsamples = 31\nvalue = [15, 16]'),
#  Text(588.5871053329796, 198.1875, 'X[0] <= 0.968\ngini = 0.495\nsamples = 29\nvalue = [13, 16]'),
#  Text(585.7445476253648, 182.3325, 'X[0] <= 0.38\ngini = 0.499\nsamples = 23\nvalue = [12, 11]'),
#  Text(584.3232687715574, 166.4775, 'X[1] <= 1.409\ngini = 0.488\nsamples = 19\nvalue = [8, 11]'),
#  Text(580.770071637039, 150.6225, 'X[0] <= -0.64\ngini = 0.444\nsamples = 15\nvalue = [5, 10]'),
#  Text(577.9275139294242, 134.7675, 'X[0] <= -0.916\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(576.5062350756168, 118.91250000000002, 'X[0] <= -1.051\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(575.0849562218095, 103.0575, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(577.9275139294242, 103.0575, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(579.3487927832316, 118.91250000000002, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(583.6126293446538, 134.7675, 'X[0] <= 0.109\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(582.1913504908464, 118.91250000000002, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(585.0339081984612, 118.91250000000002, 'X[0] <= 0.182\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(583.6126293446538, 103.0575, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(586.4551870522685, 103.0575, 'X[0] <= 0.291\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(585.0339081984612, 87.20249999999999, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(587.8764659060759, 87.20249999999999, 'X[1] <= 1.387\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(586.4551870522685, 71.34750000000003, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(589.2977447598832, 71.34750000000003, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(587.8764659060759, 150.6225, 'X[0] <= -0.827\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(586.4551870522685, 134.7675, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(589.2977447598832, 134.7675, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(587.1658264791722, 166.4775, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(591.4296630405943, 182.3325, 'X[1] <= 1.377\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(590.008384186787, 166.4775, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(592.8509418944017, 166.4775, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(591.4296630405943, 198.1875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(598.5360573096312, 214.0425, 'X[0] <= 0.76\ngini = 0.337\nsamples = 14\nvalue = [3, 11]'),
#  Text(595.6934996020165, 198.1875, 'X[0] <= 0.099\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(594.2722207482091, 182.3325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(597.1147784558239, 182.3325, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(601.3786150172459, 198.1875, 'X[0] <= 1.498\ngini = 0.278\nsamples = 12\nvalue = [2, 10]'),
#  Text(599.9573361634385, 182.3325, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(602.7998938710533, 182.3325, 'X[1] <= 1.425\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(601.3786150172459, 166.4775, 'X[1] <= 1.421\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(599.9573361634385, 150.6225, 'X[0] <= 1.587\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(598.5360573096312, 134.7675, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(601.3786150172459, 134.7675, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(602.7998938710533, 150.6225, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(604.2211727248607, 166.4775, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(608.4850092862828, 245.7525, 'X[1] <= 1.467\ngini = 0.236\nsamples = 22\nvalue = [19, 3]'),
#  Text(607.0637304324755, 229.8975, 'X[1] <= 1.452\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(605.6424515786681, 214.0425, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(608.4850092862828, 214.0425, 'X[1] <= 1.46\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(607.0637304324755, 198.1875, 'X[1] <= 1.458\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(605.6424515786681, 182.3325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(608.4850092862828, 182.3325, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(609.9062881400902, 198.1875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(609.9062881400902, 229.8975, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(622.6977978243566, 261.60749999999996, 'X[1] <= 1.52\ngini = 0.219\nsamples = 32\nvalue = [4, 28]'),
#  Text(617.0126824091271, 245.7525, 'X[0] <= 1.566\ngini = 0.142\nsamples = 26\nvalue = [2, 24]'),
#  Text(612.748845847705, 229.8975, 'X[1] <= 1.506\ngini = 0.083\nsamples = 23\nvalue = [1, 22]'),
#  Text(611.3275669938976, 214.0425, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(614.1701247015123, 214.0425, 'X[1] <= 1.509\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(612.748845847705, 198.1875, 'X[0] <= 1.124\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(611.3275669938976, 182.3325, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(614.1701247015123, 182.3325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(615.5914035553197, 198.1875, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(621.2765189705492, 229.8975, 'X[0] <= 1.618\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(619.8552401167418, 214.0425, 'X[1] <= 1.486\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(618.4339612629344, 198.1875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(621.2765189705492, 198.1875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(622.6977978243566, 214.0425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(628.3829132395861, 245.7525, 'X[1] <= 1.528\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(626.9616343857787, 229.8975, 'X[0] <= -0.182\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(625.5403555319714, 214.0425, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(628.3829132395861, 214.0425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(629.8041920933935, 229.8975, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(638.3318652162377, 277.4625, 'X[1] <= 1.566\ngini = 0.463\nsamples = 44\nvalue = [28, 16]'),
#  Text(635.489307508623, 261.60749999999996, 'X[0] <= 0.812\ngini = 0.35\nsamples = 31\nvalue = [24, 7]'),
#  Text(634.0680286548156, 245.7525, 'X[0] <= 0.744\ngini = 0.444\nsamples = 21\nvalue = [14, 7]'),
#  Text(632.6467498010082, 229.8975, 'X[0] <= -0.806\ngini = 0.42\nsamples = 20\nvalue = [14, 6]'),
#  Text(631.2254709472008, 214.0425, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(634.0680286548156, 214.0425, 'X[0] <= -0.63\ngini = 0.457\nsamples = 17\nvalue = [11, 6]'),
#  Text(632.6467498010082, 198.1875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(635.489307508623, 198.1875, 'X[1] <= 1.563\ngini = 0.391\nsamples = 15\nvalue = [11, 4]'),
#  Text(634.0680286548156, 182.3325, 'X[1] <= 1.553\ngini = 0.48\nsamples = 10\nvalue = [6, 4]'),
#  Text(632.6467498010082, 166.4775, 'X[0] <= -0.52\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(631.2254709472008, 150.6225, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(634.0680286548156, 150.6225, 'X[0] <= -0.156\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(632.6467498010082, 134.7675, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(635.489307508623, 134.7675, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(635.489307508623, 166.4775, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(636.9105863624303, 182.3325, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(635.489307508623, 229.8975, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(636.9105863624303, 245.7525, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(641.1744229238525, 261.60749999999996, 'X[0] <= 0.848\ngini = 0.426\nsamples = 13\nvalue = [4, 9]'),
#  Text(639.7531440700451, 245.7525, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(642.5957017776599, 245.7525, 'X[1] <= 1.569\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(641.1744229238525, 229.8975, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(644.0169806314673, 229.8975, 'X[1] <= 1.587\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(642.5957017776599, 214.0425, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(645.4382594852746, 214.0425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(652.5446537543115, 356.73749999999995, 'X[1] <= 1.599\ngini = 0.152\nsamples = 411\nvalue = [377, 34]'),
#  Text(643.3063412045635, 340.8825, 'X[0] <= -1.342\ngini = 0.022\nsamples = 354\nvalue = [350, 4]'),
#  Text(639.7531440700451, 325.0275, 'X[0] <= -1.436\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(638.3318652162377, 309.1725, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(641.1744229238525, 309.1725, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(646.859538339082, 325.0275, 'X[0] <= 0.978\ngini = 0.017\nsamples = 352\nvalue = [349, 3]'),
#  ...]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_absolute_error

# %%
clf=RandomForestClassifier(n_estimators=100)
clf.fit(X_train, Y_train)
# Out:
# <ipython-input-32-bde77b936d00>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_train, Y_train)
# RandomForestClassifier()

# %%
Yhat = clf.predict(X_test)
print (Yhat)
# evaluate predictions
mae = mean_absolute_error(Y_test, Yhat)
print('MAE: %.3f' % mae)
# Out:
# [1 1 0 ... 1 0 0]
# MAE: 0.129

# %%
accuracy_score(Y_test, Y_pred)
# Out:
# 0.8555783709787816

# %%
import pandas as pd
feature_imp = pd.Series(clf.feature_importances_,index =['author','source']).sort_values(ascending=False)
feature_imp
# Out:
# source    0.645675
# author    0.354325
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Creating a bar plot
sns.barplot(x=feature_imp, y=feature_imp.index)
# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.legend()
plt.show()
# Out:
# <AxesSubplot:>
# Text(0.5, 0, 'Feature Importance Score')
# Text(0, 0.5, 'Features')
# Text(0.5, 1.0, 'Visualizing Important Features')
# No handles with labels found to put in legend.
